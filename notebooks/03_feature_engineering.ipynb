# %% [markdown]
# ## Notebook 03 - Feature Engineering

# %%
# Load libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from category_encoders import TargetEncoder
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import Binarizer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MaxAbsScaler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler

import sys
sys.path.append('../src')
from paths import TRANSFORMED_DATA_DIR

#Automcomplete
# %config IPCompleter.greedy=True

# %%
# Load the cleaned dataset
data_quality = pd.read_csv(TRANSFORMED_DATA_DIR / 'data_quality.csv')

# %%
data_quality
# Out:
#       week        date  day         home score           away   xG  xG_1  \
# 0        1  2018-08-17  Fri       Girona   0–0     Valladolid  0.7   0.0
# 1        1  2018-08-17  Fri        Betis   0–3        Levante  0.9   2.5
# 2        1  2018-08-18  Sat   Celta Vigo   1–1       Espanyol  0.6   0.6
# 3        1  2018-08-18  Sat   Villarreal   1–2  Real Sociedad  1.6   0.7
# 4        1  2018-08-18  Sat    Barcelona   3–0         Alavés  3.2   0.3
# ...    ...         ...  ...          ...   ...            ...  ...   ...
# 2275    38  2024-05-25  Sat  Real Madrid   0–0          Betis  1.0   0.7
# 2276    38  2024-05-26  Sun       Getafe   1–2       Mallorca  0.9   1.4
# 2277    38  2024-05-26  Sun   Las Palmas   1–1         Alavés  1.0   2.5
# 2278    38  2024-05-26  Sun   Celta Vigo   2–2       Valencia  1.5   2.0
# 2279    38  2024-05-26  Sun      Sevilla   1–2      Barcelona  1.5   1.3
#
#                               venue                   referee
# 0     Estadi Municipal de Montilivi          Guillermo Cuadra
# 1         Estadio Benito Villamarín          Ignacio Iglesias
# 2               Estadio de Balaídos            Santiago Jaime
# 3            Estadio de la Cerámica              Mario Melero
# 4                          Camp Nou              José Sánchez
# ...                             ...                       ...
# 2275      Estadio Santiago Bernabéu       Isidro Díaz de Mera
# 2276         Coliseum Alfonso Pérez             Víctor García
# 2277        Estadio de Gran Canaria       Francisco Hernández
# 2278        Estadio Abanca Balaídos  Miguel Ángel Ortiz Arias
# 2279  Estadio Ramón Sánchez Pizjuán         Javier Villanueva
#
# [2280 rows x 10 columns]

# %% [markdown]
# ### Create features and the target variable

# %% [markdown]
# The objective of the training is to predict match results, either Home wins or Away wins, so in this section we'll be creating the features and target variables needed to build and train the model prediction dataset.
#
# An important note: I decided to train the model on the seasons before de 2023/2024 and validate it with this last season, since my initial idea is to predict the matches for the upcoming La Liga 2024/2025 season, though since there's no official match calendar and, at the time I'm doing this project, the Segunda División Playoffs are not done, so we don't know which will be the teams that are going to ascend.

# %% [markdown]
# ### Feature engineering and data transformation

# %%
# Split the 'Score' column into 'HomeGoals' and 'AwayGoals' columns
data_quality[['home_goals', 'away_goals']] = data_quality['score'].str.split('–', expand=True).astype(float)

# %%
data_quality
# Out:
#       week        date  day         home score           away   xG  xG_1  \
# 0        1  2018-08-17  Fri       Girona   0–0     Valladolid  0.7   0.0
# 1        1  2018-08-17  Fri        Betis   0–3        Levante  0.9   2.5
# 2        1  2018-08-18  Sat   Celta Vigo   1–1       Espanyol  0.6   0.6
# 3        1  2018-08-18  Sat   Villarreal   1–2  Real Sociedad  1.6   0.7
# 4        1  2018-08-18  Sat    Barcelona   3–0         Alavés  3.2   0.3
# ...    ...         ...  ...          ...   ...            ...  ...   ...
# 2275    38  2024-05-25  Sat  Real Madrid   0–0          Betis  1.0   0.7
# 2276    38  2024-05-26  Sun       Getafe   1–2       Mallorca  0.9   1.4
# 2277    38  2024-05-26  Sun   Las Palmas   1–1         Alavés  1.0   2.5
# 2278    38  2024-05-26  Sun   Celta Vigo   2–2       Valencia  1.5   2.0
# 2279    38  2024-05-26  Sun      Sevilla   1–2      Barcelona  1.5   1.3
#
#                               venue                   referee  home_goals  \
# 0     Estadi Municipal de Montilivi          Guillermo Cuadra         0.0
# 1         Estadio Benito Villamarín          Ignacio Iglesias         0.0
# 2               Estadio de Balaídos            Santiago Jaime         1.0
# 3            Estadio de la Cerámica              Mario Melero         1.0
# 4                          Camp Nou              José Sánchez         3.0
# ...                             ...                       ...         ...
# 2275      Estadio Santiago Bernabéu       Isidro Díaz de Mera         0.0
# 2276         Coliseum Alfonso Pérez             Víctor García         1.0
# 2277        Estadio de Gran Canaria       Francisco Hernández         1.0
# 2278        Estadio Abanca Balaídos  Miguel Ángel Ortiz Arias         2.0
# 2279  Estadio Ramón Sánchez Pizjuán         Javier Villanueva         1.0
#
#       away_goals
# 0            0.0
# 1            3.0
# 2            1.0
# 3            2.0
# 4            0.0
# ...          ...
# 2275         0.0
# 2276         2.0
# 2277         1.0
# 2278         2.0
# 2279         2.0
#
# [2280 rows x 12 columns]

# %%
# Create a season_start column so we can later train the 
data_quality['date'] = pd.to_datetime(data_quality['date'])
data_quality['season_start'] = data_quality['date'].apply(lambda x: x.year - 1 if x.month < 8 else x.year)

# %%
data_quality
# Out:
#       week       date  day         home score           away   xG  xG_1  \
# 0        1 2018-08-17  Fri       Girona   0–0     Valladolid  0.7   0.0
# 1        1 2018-08-17  Fri        Betis   0–3        Levante  0.9   2.5
# 2        1 2018-08-18  Sat   Celta Vigo   1–1       Espanyol  0.6   0.6
# 3        1 2018-08-18  Sat   Villarreal   1–2  Real Sociedad  1.6   0.7
# 4        1 2018-08-18  Sat    Barcelona   3–0         Alavés  3.2   0.3
# ...    ...        ...  ...          ...   ...            ...  ...   ...
# 2275    38 2024-05-25  Sat  Real Madrid   0–0          Betis  1.0   0.7
# 2276    38 2024-05-26  Sun       Getafe   1–2       Mallorca  0.9   1.4
# 2277    38 2024-05-26  Sun   Las Palmas   1–1         Alavés  1.0   2.5
# 2278    38 2024-05-26  Sun   Celta Vigo   2–2       Valencia  1.5   2.0
# 2279    38 2024-05-26  Sun      Sevilla   1–2      Barcelona  1.5   1.3
#
#                               venue                   referee  home_goals  \
# 0     Estadi Municipal de Montilivi          Guillermo Cuadra         0.0
# 1         Estadio Benito Villamarín          Ignacio Iglesias         0.0
# 2               Estadio de Balaídos            Santiago Jaime         1.0
# 3            Estadio de la Cerámica              Mario Melero         1.0
# 4                          Camp Nou              José Sánchez         3.0
# ...                             ...                       ...         ...
# 2275      Estadio Santiago Bernabéu       Isidro Díaz de Mera         0.0
# 2276         Coliseum Alfonso Pérez             Víctor García         1.0
# 2277        Estadio de Gran Canaria       Francisco Hernández         1.0
# 2278        Estadio Abanca Balaídos  Miguel Ángel Ortiz Arias         2.0
# 2279  Estadio Ramón Sánchez Pizjuán         Javier Villanueva         1.0
#
#       away_goals  season_start
# 0            0.0          2018
# 1            3.0          2018
# 2            1.0          2018
# 3            2.0          2018
# 4            0.0          2018
# ...          ...           ...
# 2275         0.0          2023
# 2276         2.0          2023
# 2277         1.0          2023
# 2278         2.0          2023
# 2279         2.0          2023
#
# [2280 rows x 13 columns]

# %%
# Create a target variable for the match result
def determine_result(row):
    if row['home_goals'] > row['away_goals']:
        return 'Home win'
    elif row['home_goals'] < row['away_goals']:
        return 'Away win'
    else:
        return 'Draw'

data_quality['result'] = data_quality.apply(determine_result, axis=1)

# %%
data_quality
# Out:
#       week       date  day         home score           away   xG  xG_1  \
# 0        1 2018-08-17  Fri       Girona   0–0     Valladolid  0.7   0.0
# 1        1 2018-08-17  Fri        Betis   0–3        Levante  0.9   2.5
# 2        1 2018-08-18  Sat   Celta Vigo   1–1       Espanyol  0.6   0.6
# 3        1 2018-08-18  Sat   Villarreal   1–2  Real Sociedad  1.6   0.7
# 4        1 2018-08-18  Sat    Barcelona   3–0         Alavés  3.2   0.3
# ...    ...        ...  ...          ...   ...            ...  ...   ...
# 2275    38 2024-05-25  Sat  Real Madrid   0–0          Betis  1.0   0.7
# 2276    38 2024-05-26  Sun       Getafe   1–2       Mallorca  0.9   1.4
# 2277    38 2024-05-26  Sun   Las Palmas   1–1         Alavés  1.0   2.5
# 2278    38 2024-05-26  Sun   Celta Vigo   2–2       Valencia  1.5   2.0
# 2279    38 2024-05-26  Sun      Sevilla   1–2      Barcelona  1.5   1.3
#
#                               venue                   referee  home_goals  \
# 0     Estadi Municipal de Montilivi          Guillermo Cuadra         0.0
# 1         Estadio Benito Villamarín          Ignacio Iglesias         0.0
# 2               Estadio de Balaídos            Santiago Jaime         1.0
# 3            Estadio de la Cerámica              Mario Melero         1.0
# 4                          Camp Nou              José Sánchez         3.0
# ...                             ...                       ...         ...
# 2275      Estadio Santiago Bernabéu       Isidro Díaz de Mera         0.0
# 2276         Coliseum Alfonso Pérez             Víctor García         1.0
# 2277        Estadio de Gran Canaria       Francisco Hernández         1.0
# 2278        Estadio Abanca Balaídos  Miguel Ángel Ortiz Arias         2.0
# 2279  Estadio Ramón Sánchez Pizjuán         Javier Villanueva         1.0
#
#       away_goals  season_start    result
# 0            0.0          2018      Draw
# 1            3.0          2018  Away win
# 2            1.0          2018      Draw
# 3            2.0          2018  Away win
# 4            0.0          2018  Home win
# ...          ...           ...       ...
# 2275         0.0          2023      Draw
# 2276         2.0          2023  Away win
# 2277         1.0          2023      Draw
# 2278         2.0          2023      Draw
# 2279         2.0          2023  Away win
#
# [2280 rows x 14 columns]

# %% [markdown]
# #### One Hot Encoding

# %%
# Encode 'day' as a categorical feature using pd.get_dummies
data_quality['day'] = data_quality['date'].dt.day_name()
data_quality = pd.get_dummies(data_quality, columns=['day'])

# Display the updated dataset with new features
data_quality.head()
# Out:
#    week       date        home score           away   xG  xG_1  \
# 0     1 2018-08-17      Girona   0–0     Valladolid  0.7   0.0
# 1     1 2018-08-17       Betis   0–3        Levante  0.9   2.5
# 2     1 2018-08-18  Celta Vigo   1–1       Espanyol  0.6   0.6
# 3     1 2018-08-18  Villarreal   1–2  Real Sociedad  1.6   0.7
# 4     1 2018-08-18   Barcelona   3–0         Alavés  3.2   0.3
#
#                            venue           referee  home_goals  away_goals  \
# 0  Estadi Municipal de Montilivi  Guillermo Cuadra         0.0         0.0
# 1      Estadio Benito Villamarín  Ignacio Iglesias         0.0         3.0
# 2            Estadio de Balaídos    Santiago Jaime         1.0         1.0
# 3         Estadio de la Cerámica      Mario Melero         1.0         2.0
# 4                       Camp Nou      José Sánchez         3.0         0.0
#
#    season_start    result  day_Friday  day_Monday  day_Saturday  day_Sunday  \
# 0          2018      Draw        True       False         False       False
# 1          2018  Away win        True       False         False       False
# 2          2018      Draw       False       False          True       False
# 3          2018  Away win       False       False          True       False
# 4          2018  Home win       False       False          True       False
#
#    day_Thursday  day_Tuesday  day_Wednesday
# 0         False        False          False
# 1         False        False          False
# 2         False        False          False
# 3         False        False          False
# 4         False        False          False

# %% [markdown]
# ### Creating new features

# %%
# Let's create some new features
data_quality.reset_index(drop=True, inplace=True)
data_quality.sort_values(['date'], inplace=True)

# %%
data_quality
# Out:
#       week       date           home score             away   xG  xG_1  \
# 0        1 2018-08-17         Girona   0–0       Valladolid  0.7   0.0
# 1        1 2018-08-17          Betis   0–3          Levante  0.9   2.5
# 2        1 2018-08-18     Celta Vigo   1–1         Espanyol  0.6   0.6
# 3        1 2018-08-18     Villarreal   1–2    Real Sociedad  1.6   0.7
# 4        1 2018-08-18      Barcelona   3–0           Alavés  3.2   0.3
# ...    ...        ...            ...   ...              ...  ...   ...
# 2272    38 2024-05-25  Real Sociedad   0–2  Atlético Madrid  0.6   2.2
# 2277    38 2024-05-26     Las Palmas   1–1           Alavés  1.0   2.5
# 2278    38 2024-05-26     Celta Vigo   2–2         Valencia  1.5   2.0
# 2276    38 2024-05-26         Getafe   1–2         Mallorca  0.9   1.4
# 2279    38 2024-05-26        Sevilla   1–2        Barcelona  1.5   1.3
#
#                               venue                   referee  home_goals  \
# 0     Estadi Municipal de Montilivi          Guillermo Cuadra         0.0
# 1         Estadio Benito Villamarín          Ignacio Iglesias         0.0
# 2               Estadio de Balaídos            Santiago Jaime         1.0
# 3            Estadio de la Cerámica              Mario Melero         1.0
# 4                          Camp Nou              José Sánchez         3.0
# ...                             ...                       ...         ...
# 2272                    Reale Arena              José Sánchez         0.0
# 2277        Estadio de Gran Canaria       Francisco Hernández         1.0
# 2278        Estadio Abanca Balaídos  Miguel Ángel Ortiz Arias         2.0
# 2276         Coliseum Alfonso Pérez             Víctor García         1.0
# 2279  Estadio Ramón Sánchez Pizjuán         Javier Villanueva         1.0
#
#       away_goals  season_start    result  day_Friday  day_Monday  \
# 0            0.0          2018      Draw        True       False
# 1            3.0          2018  Away win        True       False
# 2            1.0          2018      Draw       False       False
# 3            2.0          2018  Away win       False       False
# 4            0.0          2018  Home win       False       False
# ...          ...           ...       ...         ...         ...
# 2272         2.0          2023  Away win       False       False
# 2277         1.0          2023      Draw       False       False
# 2278         2.0          2023      Draw       False       False
# 2276         2.0          2023  Away win       False       False
# 2279         2.0          2023  Away win       False       False
#
#       day_Saturday  day_Sunday  day_Thursday  day_Tuesday  day_Wednesday
# 0            False       False         False        False          False
# 1            False       False         False        False          False
# 2             True       False         False        False          False
# 3             True       False         False        False          False
# 4             True       False         False        False          False
# ...            ...         ...           ...          ...            ...
# 2272          True       False         False        False          False
# 2277         False        True         False        False          False
# 2278         False        True         False        False          False
# 2276         False        True         False        False          False
# 2279         False        True         False        False          False
#
# [2280 rows x 20 columns]

# %% [markdown]
# ### Rolling averages

# %% [markdown]
# Since we're predicting match outcomes, this is a feature that'll help us achieve that. These are averages calculated over a moving window of data points, helping to smooth out short-term variations and reveal longer-term trends.

# %%
# First, let's isolate teams matches, so we can then calculate the rolling averages properly
for x in data_quality.home.unique():
    temp_df = data_quality[(data_quality['home'] == x) | (data_quality['away'] == x)]
    break

# %%
temp_df
# Out:
#       week       date        home score         away   xG  xG_1  \
# 0        1 2018-08-17      Girona   0–0   Valladolid  0.7   0.0
# 16       2 2018-08-26      Girona   1–4  Real Madrid  0.4   3.9
# 21       3 2018-08-31  Villarreal   0–1       Girona  1.1   1.0
# 38       4 2018-09-17      Girona   3–2   Celta Vigo  1.7   1.0
# 48       5 2018-09-23   Barcelona   2–2       Girona  1.4   1.5
# ...    ...        ...         ...   ...          ...  ...   ...
# 2233    34 2024-05-04      Girona   4–2    Barcelona  1.8   2.6
# 2240    35 2024-05-10      Alavés   2–2       Girona  1.7   1.7
# 2252    36 2024-05-14      Girona   0–1   Villarreal  1.6   0.6
# 2267    37 2024-05-19    Valencia   1–3       Girona  3.2   2.6
# 2270    38 2024-05-24      Girona   7–0      Granada  4.6   1.0
#
#                               venue              referee  home_goals  \
# 0     Estadi Municipal de Montilivi     Guillermo Cuadra         0.0
# 16    Estadi Municipal de Montilivi        Juan Martínez         1.0
# 21           Estadio de la Cerámica       Eduardo Prieto         0.0
# 38    Estadi Municipal de Montilivi            Hsu Jason         3.0
# 48                         Camp Nou            Jesús Gil         2.0
# ...                             ...                  ...         ...
# 2233  Estadi Municipal de Montilivi  Alejandro Hernández         4.0
# 2240        Estadio de Mendizorroza    José Luis Munuera         2.0
# 2252  Estadi Municipal de Montilivi         José Sánchez         0.0
# 2267            Estadio de Mestalla     Guillermo Cuadra         1.0
# 2270  Estadi Municipal de Montilivi      Alejandro Muñíz         7.0
#
#       away_goals  season_start    result  day_Friday  day_Monday  \
# 0            0.0          2018      Draw        True       False
# 16           4.0          2018  Away win       False       False
# 21           1.0          2018  Away win        True       False
# 38           2.0          2018  Home win       False        True
# 48           2.0          2018      Draw       False       False
# ...          ...           ...       ...         ...         ...
# 2233         2.0          2023  Home win       False       False
# 2240         2.0          2023      Draw        True       False
# 2252         1.0          2023  Away win       False       False
# 2267         3.0          2023  Away win       False       False
# 2270         0.0          2023  Home win        True       False
#
#       day_Saturday  day_Sunday  day_Thursday  day_Tuesday  day_Wednesday
# 0            False       False         False        False          False
# 16           False        True         False        False          False
# 21           False       False         False        False          False
# 38           False       False         False        False          False
# 48           False        True         False        False          False
# ...            ...         ...           ...          ...            ...
# 2233          True       False         False        False          False
# 2240         False       False         False        False          False
# 2252         False       False         False         True          False
# 2267         False        True         False        False          False
# 2270         False       False         False        False          False
#
# [114 rows x 20 columns]

# %%
# Update the rolling average goals for the home team in the main dataset (data_quality)
for x in data_quality.home.unique():
    temp_df = data_quality[(data_quality['home'] == x) | (data_quality['away'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['goal_value_to_calculate'] = temp_df.apply(lambda y: y['home_goals'] if y['home'] == x else y['away_goals'], axis=1)
    temp_df['rolling_avg_goals'] = temp_df['goal_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home'] == x:
            data_quality.at[index, 'home_rolling_avg_goals'] = row['rolling_avg_goals']
        else:
            data_quality.at[index, 'away_rolling_avg_goals'] = row['rolling_avg_goals']

# %%
data_quality[(data_quality['home'] == 'Real Madrid') | (data_quality['away'] == 'Real Madrid')][['week', 'date', 'home', 'away', 'home_goals', 'away_goals','home_rolling_avg_goals', 'away_rolling_avg_goals']]
# Out:
#       week       date           home         away  home_goals  away_goals  \
# 7        1 2018-08-19    Real Madrid       Getafe         2.0         0.0
# 16       2 2018-08-26         Girona  Real Madrid         1.0         4.0
# 24       3 2018-09-01    Real Madrid      Leganés         4.0         1.0
# 33       4 2018-09-15  Athletic Club  Real Madrid         1.0         1.0
# 44       5 2018-09-22    Real Madrid     Espanyol         1.0         0.0
# ...    ...        ...            ...          ...         ...         ...
# 2232    34 2024-05-04    Real Madrid        Cádiz         3.0         0.0
# 2243    35 2024-05-11        Granada  Real Madrid         0.0         4.0
# 2251    36 2024-05-14    Real Madrid       Alavés         5.0         0.0
# 2269    37 2024-05-19     Villarreal  Real Madrid         4.0         4.0
# 2275    38 2024-05-25    Real Madrid        Betis         0.0         0.0
#
#       home_rolling_avg_goals  away_rolling_avg_goals
# 7                        NaN                     NaN
# 16                      0.00                2.000000
# 24                      3.00                1.500000
# 33                      2.00                3.333333
# 44                      2.75                1.250000
# ...                      ...                     ...
# 2232                    2.20                0.600000
# 2243                    1.20                2.000000
# 2251                    2.40                1.600000
# 2269                    2.20                3.200000
# 2275                    3.40                1.600000
#
# [228 rows x 8 columns]

# %%
# Do the same thing for xG
for x in data_quality.home.unique():
    temp_df = data_quality[(data_quality['home'] == x) | (data_quality['away'] == x)]
    temp_df = temp_df.sort_values(['date'])
    
    temp_df['xG_value_to_calculate'] = temp_df.apply(lambda y: y['xG'] if y['home'] == x else y['xG_1'], axis=1)
    temp_df['rolling_avg_xG'] = temp_df['xG_value_to_calculate'].rolling(window=5, closed="left", min_periods=1).mean()
    
    for index, row in temp_df.iterrows():
        if row['home'] == x:
            data_quality.at[index, 'home_rolling_avg_xG'] = row['rolling_avg_xG']
        else:
            data_quality.at[index, 'away_rolling_avg_xG'] = row['rolling_avg_xG']

# %%
# One last bit of clean up is to drop the rows where the rolling averages are null
data_quality = data_quality.dropna(subset=['home_rolling_avg_goals', 'away_rolling_avg_goals', 'home_rolling_avg_xG', 'away_rolling_avg_xG'])

# %%
data_quality[(data_quality['home'] == 'Real Madrid') | (data_quality['away'] == 'Real Madrid')][['date', 'home', 'away', 'xG', 'xG_1','home_rolling_avg_xG', 'away_rolling_avg_xG']]
# Out:
#            date           home         away   xG  xG_1  home_rolling_avg_xG  \
# 16   2018-08-26         Girona  Real Madrid  0.4   3.9                 0.70
# 24   2018-09-01    Real Madrid      Leganés  2.5   1.1                 2.45
# 33   2018-09-15  Athletic Club  Real Madrid  1.4   1.8                 1.40
# 44   2018-09-22    Real Madrid     Espanyol  1.0   0.4                 2.30
# 54   2018-09-26        Sevilla  Real Madrid  2.4   1.5                 1.94
# ...         ...            ...          ...  ...   ...                  ...
# 2232 2024-05-04    Real Madrid        Cádiz  2.3   0.9                 1.64
# 2243 2024-05-11        Granada  Real Madrid  1.0   1.5                 1.02
# 2251 2024-05-14    Real Madrid       Alavés  2.5   1.3                 1.60
# 2269 2024-05-19     Villarreal  Real Madrid  1.7   1.0                 1.46
# 2275 2024-05-25    Real Madrid        Betis  1.0   0.7                 1.54
#
#       away_rolling_avg_xG
# 16               1.000000
# 24               1.350000
# 33               2.466667
# 44               1.175000
# 54               2.040000
# ...                   ...
# 2232             1.080000
# 2243             1.520000
# 2251             1.100000
# 2269             1.800000
# 2275             1.340000
#
# [226 rows x 7 columns]

# %%
pd.set_option('display.max_columns', None)
data_quality
# Out:
#       week       date             home score             away   xG  xG_1  \
# 10       2 2018-08-24           Getafe   2–0            Eibar  1.4   0.6
# 11       2 2018-08-24          Leganés   2–2    Real Sociedad  1.7   1.6
# 12       2 2018-08-25           Alavés   0–0            Betis  0.6   0.9
# 13       2 2018-08-25  Atlético Madrid   1–0   Rayo Vallecano  0.9   1.5
# 14       2 2018-08-25       Valladolid   0–1        Barcelona  0.4   1.0
# ...    ...        ...              ...   ...              ...  ...   ...
# 2272    38 2024-05-25    Real Sociedad   0–2  Atlético Madrid  0.6   2.2
# 2277    38 2024-05-26       Las Palmas   1–1           Alavés  1.0   2.5
# 2278    38 2024-05-26       Celta Vigo   2–2         Valencia  1.5   2.0
# 2276    38 2024-05-26           Getafe   1–2         Mallorca  0.9   1.4
# 2279    38 2024-05-26          Sevilla   1–2        Barcelona  1.5   1.3
#
#                                 venue                   referee  home_goals  \
# 10             Coliseum Alfonso Pérez               David Medié         2.0
# 11      Estadio Municipal de Butarque         José Luis Munuera         2.0
# 12            Estadio de Mendizorroza            Pablo González         0.0
# 13        Estadio Wanda Metropolitano             José González         1.0
# 14    Estadio Municipal José Zorrilla         Ricardo de Burgos         0.0
# ...                               ...                       ...         ...
# 2272                      Reale Arena              José Sánchez         0.0
# 2277          Estadio de Gran Canaria       Francisco Hernández         1.0
# 2278          Estadio Abanca Balaídos  Miguel Ángel Ortiz Arias         2.0
# 2276           Coliseum Alfonso Pérez             Víctor García         1.0
# 2279    Estadio Ramón Sánchez Pizjuán         Javier Villanueva         1.0
#
#       away_goals  season_start    result  day_Friday  day_Monday  \
# 10           0.0          2018  Home win        True       False
# 11           2.0          2018      Draw        True       False
# 12           0.0          2018      Draw       False       False
# 13           0.0          2018  Home win       False       False
# 14           1.0          2018  Away win       False       False
# ...          ...           ...       ...         ...         ...
# 2272         2.0          2023  Away win       False       False
# 2277         1.0          2023      Draw       False       False
# 2278         2.0          2023      Draw       False       False
# 2276         2.0          2023  Away win       False       False
# 2279         2.0          2023  Away win       False       False
#
#       day_Saturday  day_Sunday  day_Thursday  day_Tuesday  day_Wednesday  \
# 10           False       False         False        False          False
# 11           False       False         False        False          False
# 12            True       False         False        False          False
# 13            True       False         False        False          False
# 14            True       False         False        False          False
# ...            ...         ...           ...          ...            ...
# 2272          True       False         False        False          False
# 2277         False        True         False        False          False
# 2278         False        True         False        False          False
# 2276         False        True         False        False          False
# 2279         False        True         False        False          False
#
#       home_rolling_avg_goals  away_rolling_avg_goals  home_rolling_avg_xG  \
# 10                       0.0                     1.0                 0.20
# 11                       1.0                     2.0                 1.00
# 12                       0.0                     0.0                 0.30
# 13                       1.0                     1.0                 0.90
# 14                       0.0                     3.0                 0.00
# ...                      ...                     ...                  ...
# 2272                     1.0                     1.8                 0.72
# 2277                     0.4                     1.4                 1.08
# 2278                     1.4                     0.6                 1.38
# 2276                     0.6                     1.0                 1.52
# 2279                     1.2                     2.6                 1.40
#
#       away_rolling_avg_xG
# 10                   1.30
# 11                   0.70
# 12                   0.90
# 13                   2.10
# 14                   3.20
# ...                   ...
# 2272                 1.16
# 2277                 1.46
# 2278                 1.66
# 2276                 1.08
# 2279                 1.96
#
# [2263 rows x 24 columns]
