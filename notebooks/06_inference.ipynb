# %% [markdown]
# # Notebook 06 - Inference

# %%
import warnings
warnings.filterwarnings("ignore")

import sys
sys.path.append('../src')

import os
import hopsworks
from comet_ml import API, APIExperiment, Model
import pandas as pd
import xgboost as xgb
from dotenv import load_dotenv
from paths import PARENT_DIR

# Load API keys from .env
load_dotenv(PARENT_DIR / '.env')
HOPSWORKS_API_KEY = os.environ['HOPSWORKS_API_KEY']
HOPSWORKS_PROJECT_NAME = 'rheredia8'
COMET_API_KEY = os.environ['COMET_API_KEY']
COMET_PROJECT_NAME = 'mle-soccer-project'
COMET_WORKSPACE = 'rheredia8'
COMET_MODEL_NAME = 'prime_church_4035'

# %%
# Hopsworks configs
project = hopsworks.login(api_key_value=HOPSWORKS_API_KEY)
feature_store = project.get_feature_store()

# Obtener el grupo de características
FEATURE_GROUP_NAME = 'la_liga_features'
FEATURE_GROUP_VERSION = 1
feature_group = feature_store.get_feature_group(
    name=FEATURE_GROUP_NAME,
    version=FEATURE_GROUP_VERSION
)

# Cargar los datos transformados
data_transformed = feature_group.read()
data_transformed.head()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/445590
# Connected. Call `.close()` to terminate connection gracefully.
# Finished: Reading data from Hopsworks, using Hopsworks Feature Query Service (1.40s)
#    week                      date             home score            away   xg  \
# 0    23 2022-02-05 00:00:00+00:00       Celta Vigo   2–0  Rayo Vallecano  0.7
# 1    13 2023-11-12 00:00:00+00:00        Barcelona   2–1          Alavés  1.6
# 2    30 2024-03-31 00:00:00+00:00           Girona   3–2           Betis  2.6
# 3    12 2018-11-11 00:00:00+00:00          Sevilla   2–1        Espanyol  4.1
# 4    18 2023-12-19 00:00:00+00:00  Atlético Madrid   3–3          Getafe  2.0
#
#    xg_1                          venue            referee  home_goals  ...  \
# 0   0.8            Estadio de Balaídos  José Luis Munuera         2.0  ...
# 1   1.7  Estadi Olímpic Lluís Companys     Mateo Busquets         2.0  ...
# 2   0.5  Estadi Municipal de Montilivi          Jesús Gil         3.0  ...
# 3   0.8  Estadio Ramón Sánchez Pizjuán     Santiago Jaime         2.0  ...
# 4   2.0  Estadio Cívitas Metropolitano  José Luis Munuera         3.0  ...
#
#    day_monday  day_saturday day_sunday  day_thursday  day_tuesday  \
# 0       False          True      False         False        False
# 1       False         False       True         False        False
# 2       False         False       True         False        False
# 3       False         False       True         False        False
# 4       False         False      False         False         True
#
#    day_wednesday  home_rolling_avg_goals  away_rolling_avg_goals  \
# 0          False                     1.8                     0.6
# 1          False                     1.2                     0.8
# 2          False                     1.4                     1.2
# 3          False                     1.8                     1.8
# 4          False                     1.2                     1.4
#
#    home_rolling_avg_xg  away_rolling_avg_xg
# 0                 1.22                 1.32
# 1                 1.88                 1.48
# 2                 1.80                 0.88
# 3                 1.62                 1.52
# 4                 1.76                 1.50
#
# [5 rows x 24 columns]
